# %%
import pandas as pd

data= pd.read_csv('../Data/particle_times_output.csv')

# %%
data
# Out:
#         source_file  fuel_density  coolant_density  radius  \
# 0    pu240source.py          19.0             0.45     0.5
# 1    pu240source.py          19.0             0.45     1.0
# 2    pu240source.py          19.0             0.45     1.5
# 3    pu240source.py          19.0             0.45     2.0
# 4    pu240source.py          19.0             0.45     2.5
# ..              ...           ...              ...     ...
# 156  pu240source.py          19.2             0.55     3.5
# 157  pu240source.py          19.2             0.55     4.0
# 158  pu240source.py          19.2             0.55     4.5
# 159  pu240source.py          19.2             0.55     5.0
# 160  pu240source.py          19.0             1.00     1.0
#
#                                         particle_times
# 0    [4.19530048e-08 1.34116852e-07 2.05753702e-07 ...
# 1    [4.19530048e-08 1.34116852e-07 4.11209976e-07 ...
# 2    [4.19530048e-08 1.34116852e-07 4.30157407e-07 ...
# ...

# %%
# Convert particle_times to strings for comparison and count duplicates
duplicate_counts = data['particle_times'].astype(str).value_counts()

# Show how many times each unique particle_times sequence appears
print("Number of duplicate particle_times sequences:")
print(duplicate_counts)

# Show total number of unique sequences
print("\nTotal number of unique sequences:", len(duplicate_counts))
# Out:
# Number of duplicate particle_times sequences:
# particle_times
# [4.19530048e-08 1.34116852e-07 4.30157407e-07 ... 8.48162038e-09\n 4.64213266e-08 1.29476952e-07]    56
# [4.17333555e-08 1.33414670e-07 4.27905274e-07 ... 8.43721399e-09\n 4.61782830e-08 1.28799062e-07]    56
# [4.15159943e-08 1.32719802e-07 4.25676601e-07 ... 8.39327017e-09\n 4.59377711e-08 1.28128233e-07]    16
# [4.19530048e-08 1.34116852e-07 2.05753702e-07 ... 8.48162038e-09\n 4.64213266e-08 1.29476952e-07]     8
# [4.19530048e-08 1.34116852e-07 4.11209976e-07 ... 8.48162038e-09\n 4.64213266e-08 1.29476952e-07]     7
# [4.17333555e-08 1.33414670e-07 2.05801669e-07 ... 8.43721399e-09\n 4.61782830e-08 1.28799062e-07]     7
# [4.17333555e-08 1.33414670e-07 4.11161366e-07 ... 8.43721399e-09\n 4.61782830e-08 1.28799062e-07]     7
# [4.15159943e-08 1.32719802e-07 2.05848020e-07 ... 8.39327017e-09\n 4.59377711e-08 1.28128233e-07]     2
# ...
