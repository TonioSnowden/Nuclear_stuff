# %%
import pandas as pd

file_path = "../../Data/cmsr_dataset_shuffled.csv"
df_base = pd.read_csv(file_path, nrows = 1000)

# %%
df_base
# Out:
#         IE            BU      CT  FMI       fuel_H1       fuel_H2  \
# 0    11.00  1.217610e+01   730.0   31  1.746580e-06  9.462870e-09
# 1    19.00  2.162690e+01     1.0   24  2.855400e-06  1.547670e-08
# 2    20.00  4.088070e-02     0.0   27  5.092890e-09  2.662800e-11
# 3    11.75  6.066160e+00  2920.0    2  8.377580e-07  4.493090e-09
# 4    11.75  7.736500e+00  1825.0   30  1.076840e-06  5.781020e-09
# ..     ...           ...     ...  ...           ...           ...
# 995  17.75  2.751800e-09  1825.0    9  3.461410e-16  1.807550e-18
# 996  10.00  2.276980e+01   365.0   17  3.478230e-06  1.944990e-08
# 997  18.25  2.751800e-09   730.0   32  3.425830e-16  1.797880e-18
# 998  14.75  2.720950e+01    30.0   32  3.773790e-06  2.083140e-08
# 999  18.00  2.720950e+01   730.0    4  3.650100e-06  1.991820e-08
#
#           fuel_H3      fuel_He3      fuel_He4      fuel_Li6  ...  \
# 0    1.824010e-09  5.432780e-10  1.008170e-05  2.916550e-21  ...
# ...
